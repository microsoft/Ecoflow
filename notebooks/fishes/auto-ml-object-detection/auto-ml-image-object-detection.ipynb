# %%
import azureml.core

print("This notebook was created using version 1.35.0 of the Azure ML SDK.")
print("You are currently using version", azureml.core.VERSION, "of the Azure ML SDK.")
assert (
    azureml.core.VERSION >= "1.35"
), "Please upgrade the Azure ML SDK by running '!pip install --upgrade azureml-sdk' then restart the kernel."
# Out:
# This notebook was created using version 1.35.0 of the Azure ML SDK.
# You are currently using version 1.41.0 of the Azure ML SDK.

# %% [markdown]
# ## Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# Create an Azure ML Workspace within your Azure subscription or load an existing workspace.

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()

# %% [markdown]
# ## Compute target setup
# You will need to provide a [Compute Target](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#computes) that will be used for your AutoML model training. AutoML models for image tasks require [GPU SKUs](https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-gpu) such as the ones from the NC, NCv2, NCv3, ND, NDv2 and NCasT4 series. We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "gpu-cluster-nc6"

try:
    compute_target = ws.compute_targets[cluster_name]
    print("Found existing compute target.")
except KeyError:
    print("Creating a new compute target...")
    compute_config = AmlCompute.provisioning_configuration(
        vm_size="Standard_NC6",
        idle_seconds_before_scaledown=600,
        min_nodes=0,
        max_nodes=4,
    )
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(
    show_output=True, min_node_count=None, timeout_in_minutes=20
)
# Out:
# Creating a new compute target...
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#experiments) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = "automl-image-object-detection"
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Dataset with input Training Data
#
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an [AzureML Tabular Dataset](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.data.tabulardataset). You can either use a dataset that you have exported from a [Data Labeling](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-label-data) project, or create a new Tabular Dataset with your labeled training data.

# %% [markdown]
# In this notebook, we use a toy dataset called Fridge Objects, which consists of 128 images of 4 classes of beverage container {can, carton, milk bottle, water bottle} photos taken on different backgrounds.
#
# All images in this notebook are hosted in [this repository](https://github.com/microsoft/computervision-recipes) and are made available under the [MIT license](https://github.com/microsoft/computervision-recipes/blob/master/LICENSE).
#
# We first download and unzip the data locally.

# %%
import os
import urllib
from zipfile import ZipFile

# download data
download_url = "https://cvbp-secondary.z19.web.core.windows.net/datasets/object_detection/odFridgeObjects.zip"
data_file = "./odFridgeObjects.zip"
urllib.request.urlretrieve(download_url, filename=data_file)

# extract files
with ZipFile(data_file, "r") as zip:
    print("extracting files...")
    zip.extractall()
    print("done")
# delete zip file
os.remove(data_file)
# Out:
# extracting files...
# done

# %% [markdown]
# This is a sample image from this dataset:

# %%
from IPython.display import Image

Image(filename="./odFridgeObjects/images/31.jpg")

# %% [markdown]
# ### Convert the downloaded data to JSONL
# In this example, the fridge object dataset is annotated in Pascal VOC format, where each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located and also contains information about the bounding boxes and the object labels. In order to use this data to create an [AzureML Tabular Dataset](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.data.tabulardataset), we first need to convert it to the required JSONL format. Please refer to the [documentation on how to prepare datasets](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-prepare-datasets-for-automl-images).
#
# The following script is creating two .jsonl files (one for training and one for validation) in the parent folder of the dataset. The train / validation ratio corresponds to 20% of the data going into the validation file.

# %%
import json
import os
import xml.etree.ElementTree as ET

src = "./odFridgeObjects/"
train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the annotations
annotations_folder = os.path.join(src, "annotations")

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = {
    "image_url": "AmlDatastore://"
    + workspaceblobstore
    + "/"
    + os.path.basename(os.path.dirname(src))
    + "/"
    + "images",
    "image_details": {"format": None, "width": None, "height": None},
    "label": [],
}

# Read each annotation and convert it to jsonl line
with open(train_annotations_file, "w") as train_f:
    with open(validation_annotations_file, "w") as validation_f:
        for i, filename in enumerate(os.listdir(annotations_folder)):
            if filename.endswith(".xml"):
                print("Parsing " + os.path.join(src, filename))

                root = ET.parse(os.path.join(annotations_folder, filename)).getroot()

                width = int(root.find("size/width").text)
                height = int(root.find("size/height").text)

                labels = []
                for object in root.findall("object"):
                    name = object.find("name").text
                    xmin = object.find("bndbox/xmin").text
                    ymin = object.find("bndbox/ymin").text
                    xmax = object.find("bndbox/xmax").text
                    ymax = object.find("bndbox/ymax").text
                    isCrowd = int(object.find("difficult").text)
                    labels.append(
                        {
                            "label": name,
                            "topX": float(xmin) / width,
                            "topY": float(ymin) / height,
                            "bottomX": float(xmax) / width,
                            "bottomY": float(ymax) / height,
                            "isCrowd": isCrowd,
                        }
                    )
                # build the jsonl file
                image_filename = root.find("filename").text
                _, file_extension = os.path.splitext(image_filename)
                json_line = dict(json_line_sample)
                json_line["image_url"] = json_line["image_url"] + "/" + image_filename
                json_line["image_details"]["format"] = file_extension[1:]
                json_line["image_details"]["width"] = width
                json_line["image_details"]["height"] = height
                json_line["label"] = labels

                if i % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
            else:
                print("Skipping unknown file: {}".format(filename))
# Out:
# Parsing ./odFridgeObjects/1.xml
# Parsing ./odFridgeObjects/10.xml
# Parsing ./odFridgeObjects/100.xml
# Parsing ./odFridgeObjects/101.xml
# Parsing ./odFridgeObjects/102.xml
# Parsing ./odFridgeObjects/103.xml
# Parsing ./odFridgeObjects/104.xml
# Parsing ./odFridgeObjects/105.xml
# Parsing ./odFridgeObjects/106.xml
# Parsing ./odFridgeObjects/107.xml
# Parsing ./odFridgeObjects/108.xml
# Parsing ./odFridgeObjects/109.xml
# Parsing ./odFridgeObjects/11.xml
# Parsing ./odFridgeObjects/110.xml
# Parsing ./odFridgeObjects/111.xml
# Parsing ./odFridgeObjects/112.xml
# Parsing ./odFridgeObjects/113.xml
# Parsing ./odFridgeObjects/114.xml
# Parsing ./odFridgeObjects/115.xml
# Parsing ./odFridgeObjects/116.xml
# Parsing ./odFridgeObjects/117.xml
# Parsing ./odFridgeObjects/118.xml
# Parsing ./odFridgeObjects/119.xml
# Parsing ./odFridgeObjects/12.xml
# Parsing ./odFridgeObjects/120.xml
# Parsing ./odFridgeObjects/121.xml
# Parsing ./odFridgeObjects/122.xml
# Parsing ./odFridgeObjects/123.xml
# Parsing ./odFridgeObjects/124.xml
# Parsing ./odFridgeObjects/125.xml
# Parsing ./odFridgeObjects/126.xml
# Parsing ./odFridgeObjects/127.xml
# Parsing ./odFridgeObjects/128.xml
# Parsing ./odFridgeObjects/13.xml
# Parsing ./odFridgeObjects/14.xml
# Parsing ./odFridgeObjects/15.xml
# Parsing ./odFridgeObjects/16.xml
# Parsing ./odFridgeObjects/17.xml
# Parsing ./odFridgeObjects/18.xml
# Parsing ./odFridgeObjects/19.xml
# Parsing ./odFridgeObjects/2.xml
# Parsing ./odFridgeObjects/20.xml
# Parsing ./odFridgeObjects/21.xml
# Parsing ./odFridgeObjects/22.xml
# Parsing ./odFridgeObjects/23.xml
# Parsing ./odFridgeObjects/24.xml
# Parsing ./odFridgeObjects/25.xml
# Parsing ./odFridgeObjects/26.xml
# Parsing ./odFridgeObjects/27.xml
# Parsing ./odFridgeObjects/28.xml
# Parsing ./odFridgeObjects/29.xml
# Parsing ./odFridgeObjects/3.xml
# Parsing ./odFridgeObjects/30.xml
# Parsing ./odFridgeObjects/31.xml
# Parsing ./odFridgeObjects/32.xml
# Parsing ./odFridgeObjects/33.xml
# Parsing ./odFridgeObjects/34.xml
# Parsing ./odFridgeObjects/35.xml
# Parsing ./odFridgeObjects/36.xml
# Parsing ./odFridgeObjects/37.xml
# Parsing ./odFridgeObjects/38.xml
# Parsing ./odFridgeObjects/39.xml
# Parsing ./odFridgeObjects/4.xml
# Parsing ./odFridgeObjects/40.xml
# Parsing ./odFridgeObjects/41.xml
# Parsing ./odFridgeObjects/42.xml
# Parsing ./odFridgeObjects/43.xml
# Parsing ./odFridgeObjects/44.xml
# Parsing ./odFridgeObjects/45.xml
# Parsing ./odFridgeObjects/46.xml
# Parsing ./odFridgeObjects/47.xml
# Parsing ./odFridgeObjects/48.xml
# Parsing ./odFridgeObjects/49.xml
# Parsing ./odFridgeObjects/5.xml
# Parsing ./odFridgeObjects/50.xml
# Parsing ./odFridgeObjects/51.xml
# Parsing ./odFridgeObjects/52.xml
# Parsing ./odFridgeObjects/53.xml
# Parsing ./odFridgeObjects/54.xml
# Parsing ./odFridgeObjects/55.xml
# Parsing ./odFridgeObjects/56.xml
# Parsing ./odFridgeObjects/57.xml
# Parsing ./odFridgeObjects/58.xml
# Parsing ./odFridgeObjects/59.xml
# Parsing ./odFridgeObjects/6.xml
# Parsing ./odFridgeObjects/60.xml
# Parsing ./odFridgeObjects/61.xml
# Parsing ./odFridgeObjects/62.xml
# Parsing ./odFridgeObjects/63.xml
# Parsing ./odFridgeObjects/64.xml
# Parsing ./odFridgeObjects/65.xml
# Parsing ./odFridgeObjects/66.xml
# Parsing ./odFridgeObjects/67.xml
# Parsing ./odFridgeObjects/68.xml
# Parsing ./odFridgeObjects/69.xml
# Parsing ./odFridgeObjects/7.xml
# Parsing ./odFridgeObjects/70.xml
# Parsing ./odFridgeObjects/71.xml
# Parsing ./odFridgeObjects/72.xml
# Parsing ./odFridgeObjects/73.xml
# Parsing ./odFridgeObjects/74.xml
# Parsing ./odFridgeObjects/75.xml
# Parsing ./odFridgeObjects/76.xml
# Parsing ./odFridgeObjects/77.xml
# Parsing ./odFridgeObjects/78.xml
# Parsing ./odFridgeObjects/79.xml
# Parsing ./odFridgeObjects/8.xml
# Parsing ./odFridgeObjects/80.xml
# Parsing ./odFridgeObjects/81.xml
# Parsing ./odFridgeObjects/82.xml
# Parsing ./odFridgeObjects/83.xml
# Parsing ./odFridgeObjects/84.xml
# Parsing ./odFridgeObjects/85.xml
# Parsing ./odFridgeObjects/86.xml
# Parsing ./odFridgeObjects/87.xml
# Parsing ./odFridgeObjects/88.xml
# Parsing ./odFridgeObjects/89.xml
# Parsing ./odFridgeObjects/9.xml
# Parsing ./odFridgeObjects/90.xml
# Parsing ./odFridgeObjects/91.xml
# Parsing ./odFridgeObjects/92.xml
# Parsing ./odFridgeObjects/93.xml
# Parsing ./odFridgeObjects/94.xml
# Parsing ./odFridgeObjects/95.xml
# Parsing ./odFridgeObjects/96.xml
# Parsing ./odFridgeObjects/97.xml
# Parsing ./odFridgeObjects/98.xml
# Parsing ./odFridgeObjects/99.xml

# %% [markdown]
# ### Convert annotation file from COCO to JSONL
# If you want to try with a dataset in COCO format, the scripts below shows how to convert it to `jsonl` format. The file "odFridgeObjects_coco.json" consists of annotation information for the `odFridgeObjects` dataset.

# %%
# Generate jsonl file from coco file
# !python coco2jsonl.py \
--input_coco_file_path "./odFridgeObjects_coco.json" \
--output_dir "./odFridgeObjects" --output_file_name "odFridgeObjects_from_coco.jsonl" \
--task_type "ObjectDetection" \
--base_url "AmlDatastore://workspaceblobstore/odFridgeObjects/images/"
# Out:
# Converting for ObjectDetection
# Conversion completed. Converted 128 lines.

# %% [markdown]
# ### Visualize bounding boxes
# Please refer to the "Visualize data" section in the following [tutorial](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-auto-train-image-models#visualize-data) to see how to easily visualize your ground truth bounding boxes before starting to train.

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir="./odFridgeObjects", target_path="odFridgeObjects")
# Out:
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# Uploading an estimated of 260 files
# Uploading ./odFridgeObjects\.DS_Store
# Uploaded ./odFridgeObjects\.DS_Store, 1 files out of an estimated total of 260
# Uploading ./odFridgeObjects\odFridgeObjects_from_coco.jsonl
# Uploaded ./odFridgeObjects\odFridgeObjects_from_coco.jsonl, 2 files out of an estimated total of 260
# Uploading ./odFridgeObjects\train_annotations.jsonl
# Uploaded ./odFridgeObjects\train_annotations.jsonl, 3 files out of an estimated total of 260
# Uploading ./odFridgeObjects\validation_annotations.jsonl
# Uploaded ./odFridgeObjects\validation_annotations.jsonl, 4 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\1.xml
# Uploaded ./odFridgeObjects\annotations\1.xml, 5 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\10.xml
# Uploaded ./odFridgeObjects\annotations\10.xml, 6 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\100.xml
# Uploaded ./odFridgeObjects\annotations\100.xml, 7 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\101.xml
# Uploaded ./odFridgeObjects\annotations\101.xml, 8 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\102.xml
# Uploaded ./odFridgeObjects\annotations\102.xml, 9 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\103.xml
# Uploaded ./odFridgeObjects\annotations\103.xml, 10 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\104.xml
# Uploaded ./odFridgeObjects\annotations\104.xml, 11 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\105.xml
# Uploaded ./odFridgeObjects\annotations\105.xml, 12 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\106.xml
# Uploaded ./odFridgeObjects\annotations\106.xml, 13 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\107.xml
# Uploaded ./odFridgeObjects\annotations\107.xml, 14 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\108.xml
# Uploaded ./odFridgeObjects\annotations\108.xml, 15 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\109.xml
# Uploaded ./odFridgeObjects\annotations\109.xml, 16 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\11.xml
# Uploaded ./odFridgeObjects\annotations\11.xml, 17 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\110.xml
# Uploaded ./odFridgeObjects\annotations\110.xml, 18 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\111.xml
# Uploaded ./odFridgeObjects\annotations\111.xml, 19 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\112.xml
# Uploaded ./odFridgeObjects\annotations\112.xml, 20 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\113.xml
# Uploaded ./odFridgeObjects\annotations\113.xml, 21 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\114.xml
# Uploaded ./odFridgeObjects\annotations\114.xml, 22 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\115.xml
# Uploaded ./odFridgeObjects\annotations\115.xml, 23 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\116.xml
# Uploaded ./odFridgeObjects\annotations\116.xml, 24 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\117.xml
# Uploaded ./odFridgeObjects\annotations\117.xml, 25 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\118.xml
# Uploaded ./odFridgeObjects\annotations\118.xml, 26 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\119.xml
# Uploaded ./odFridgeObjects\annotations\119.xml, 27 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\12.xml
# Uploaded ./odFridgeObjects\annotations\12.xml, 28 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\120.xml
# Uploaded ./odFridgeObjects\annotations\120.xml, 29 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\121.xml
# Uploaded ./odFridgeObjects\annotations\121.xml, 30 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\122.xml
# Uploaded ./odFridgeObjects\annotations\122.xml, 31 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\123.xml
# Uploaded ./odFridgeObjects\annotations\123.xml, 32 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\124.xml
# Uploaded ./odFridgeObjects\annotations\124.xml, 33 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\125.xml
# Uploaded ./odFridgeObjects\annotations\125.xml, 34 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\126.xml
# Uploaded ./odFridgeObjects\annotations\126.xml, 35 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\127.xml
# Uploaded ./odFridgeObjects\annotations\127.xml, 36 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\128.xml
# Uploaded ./odFridgeObjects\annotations\128.xml, 37 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\13.xml
# Uploaded ./odFridgeObjects\annotations\13.xml, 38 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\14.xml
# Uploaded ./odFridgeObjects\annotations\14.xml, 39 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\15.xml
# Uploaded ./odFridgeObjects\annotations\15.xml, 40 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\16.xml
# Uploaded ./odFridgeObjects\annotations\16.xml, 41 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\17.xml
# Uploaded ./odFridgeObjects\annotations\17.xml, 42 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\18.xml
# Uploaded ./odFridgeObjects\annotations\18.xml, 43 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\19.xml
# Uploaded ./odFridgeObjects\annotations\19.xml, 44 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\2.xml
# Uploaded ./odFridgeObjects\annotations\2.xml, 45 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\20.xml
# Uploaded ./odFridgeObjects\annotations\20.xml, 46 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\21.xml
# Uploaded ./odFridgeObjects\annotations\21.xml, 47 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\22.xml
# Uploaded ./odFridgeObjects\annotations\22.xml, 48 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\23.xml
# Uploaded ./odFridgeObjects\annotations\23.xml, 49 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\24.xml
# Uploaded ./odFridgeObjects\annotations\24.xml, 50 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\25.xml
# Uploaded ./odFridgeObjects\annotations\25.xml, 51 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\26.xml
# Uploaded ./odFridgeObjects\annotations\26.xml, 52 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\27.xml
# Uploaded ./odFridgeObjects\annotations\27.xml, 53 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\28.xml
# Uploaded ./odFridgeObjects\annotations\28.xml, 54 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\29.xml
# Uploaded ./odFridgeObjects\annotations\29.xml, 55 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\3.xml
# Uploaded ./odFridgeObjects\annotations\3.xml, 56 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\30.xml
# Uploaded ./odFridgeObjects\annotations\30.xml, 57 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\31.xml
# Uploaded ./odFridgeObjects\annotations\31.xml, 58 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\32.xml
# Uploaded ./odFridgeObjects\annotations\32.xml, 59 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\33.xml
# Uploaded ./odFridgeObjects\annotations\33.xml, 60 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\34.xml
# Uploaded ./odFridgeObjects\annotations\34.xml, 61 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\35.xml
# Uploaded ./odFridgeObjects\annotations\35.xml, 62 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\36.xml
# Uploaded ./odFridgeObjects\annotations\36.xml, 63 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\37.xml
# Uploaded ./odFridgeObjects\annotations\37.xml, 64 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\38.xml
# Uploaded ./odFridgeObjects\annotations\38.xml, 65 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\39.xml
# Uploaded ./odFridgeObjects\annotations\39.xml, 66 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\4.xml
# Uploaded ./odFridgeObjects\annotations\4.xml, 67 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\40.xml
# Uploaded ./odFridgeObjects\annotations\40.xml, 68 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\41.xml
# Uploaded ./odFridgeObjects\annotations\41.xml, 69 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\42.xml
# Uploaded ./odFridgeObjects\annotations\42.xml, 70 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\43.xml
# Uploaded ./odFridgeObjects\annotations\43.xml, 71 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\44.xml
# Uploaded ./odFridgeObjects\annotations\44.xml, 72 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\45.xml
# Uploaded ./odFridgeObjects\annotations\45.xml, 73 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\46.xml
# Uploaded ./odFridgeObjects\annotations\46.xml, 74 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\47.xml
# Uploaded ./odFridgeObjects\annotations\47.xml, 75 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\48.xml
# Uploaded ./odFridgeObjects\annotations\48.xml, 76 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\49.xml
# Uploaded ./odFridgeObjects\annotations\49.xml, 77 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\5.xml
# Uploaded ./odFridgeObjects\annotations\5.xml, 78 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\50.xml
# Uploaded ./odFridgeObjects\annotations\50.xml, 79 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\51.xml
# Uploaded ./odFridgeObjects\annotations\51.xml, 80 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\52.xml
# Uploaded ./odFridgeObjects\annotations\52.xml, 81 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\53.xml
# Uploaded ./odFridgeObjects\annotations\53.xml, 82 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\54.xml
# Uploaded ./odFridgeObjects\annotations\54.xml, 83 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\55.xml
# Uploaded ./odFridgeObjects\annotations\55.xml, 84 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\56.xml
# Uploaded ./odFridgeObjects\annotations\56.xml, 85 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\57.xml
# Uploaded ./odFridgeObjects\annotations\57.xml, 86 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\58.xml
# Uploaded ./odFridgeObjects\annotations\58.xml, 87 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\59.xml
# Uploaded ./odFridgeObjects\annotations\59.xml, 88 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\6.xml
# Uploaded ./odFridgeObjects\annotations\6.xml, 89 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\60.xml
# Uploaded ./odFridgeObjects\annotations\60.xml, 90 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\61.xml
# Uploaded ./odFridgeObjects\annotations\61.xml, 91 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\62.xml
# Uploaded ./odFridgeObjects\annotations\62.xml, 92 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\63.xml
# Uploaded ./odFridgeObjects\annotations\63.xml, 93 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\64.xml
# Uploaded ./odFridgeObjects\annotations\64.xml, 94 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\65.xml
# Uploaded ./odFridgeObjects\annotations\65.xml, 95 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\66.xml
# Uploaded ./odFridgeObjects\annotations\66.xml, 96 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\67.xml
# Uploaded ./odFridgeObjects\annotations\67.xml, 97 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\68.xml
# Uploaded ./odFridgeObjects\annotations\68.xml, 98 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\69.xml
# Uploaded ./odFridgeObjects\annotations\69.xml, 99 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\7.xml
# Uploaded ./odFridgeObjects\annotations\7.xml, 100 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\70.xml
# Uploaded ./odFridgeObjects\annotations\70.xml, 101 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\71.xml
# Uploaded ./odFridgeObjects\annotations\71.xml, 102 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\72.xml
# Uploaded ./odFridgeObjects\annotations\72.xml, 103 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\73.xml
# Uploaded ./odFridgeObjects\annotations\73.xml, 104 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\74.xml
# Uploaded ./odFridgeObjects\annotations\74.xml, 105 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\75.xml
# Uploaded ./odFridgeObjects\annotations\75.xml, 106 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\76.xml
# Uploaded ./odFridgeObjects\annotations\76.xml, 107 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\77.xml
# Uploaded ./odFridgeObjects\annotations\77.xml, 108 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\78.xml
# Uploaded ./odFridgeObjects\annotations\78.xml, 109 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\79.xml
# Uploaded ./odFridgeObjects\annotations\79.xml, 110 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\8.xml
# Uploaded ./odFridgeObjects\annotations\8.xml, 111 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\80.xml
# Uploaded ./odFridgeObjects\annotations\80.xml, 112 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\81.xml
# Uploaded ./odFridgeObjects\annotations\81.xml, 113 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\82.xml
# Uploaded ./odFridgeObjects\annotations\82.xml, 114 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\83.xml
# Uploaded ./odFridgeObjects\annotations\83.xml, 115 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\84.xml
# Uploaded ./odFridgeObjects\annotations\84.xml, 116 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\85.xml
# Uploaded ./odFridgeObjects\annotations\85.xml, 117 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\86.xml
# Uploaded ./odFridgeObjects\annotations\86.xml, 118 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\87.xml
# Uploaded ./odFridgeObjects\annotations\87.xml, 119 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\88.xml
# Uploaded ./odFridgeObjects\annotations\88.xml, 120 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\89.xml
# Uploaded ./odFridgeObjects\annotations\89.xml, 121 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\9.xml
# Uploaded ./odFridgeObjects\annotations\9.xml, 122 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\90.xml
# Uploaded ./odFridgeObjects\annotations\90.xml, 123 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\91.xml
# Uploaded ./odFridgeObjects\annotations\91.xml, 124 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\92.xml
# Uploaded ./odFridgeObjects\annotations\92.xml, 125 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\93.xml
# Uploaded ./odFridgeObjects\annotations\93.xml, 126 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\94.xml
# Uploaded ./odFridgeObjects\annotations\94.xml, 127 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\95.xml
# Uploaded ./odFridgeObjects\annotations\95.xml, 128 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\96.xml
# Uploaded ./odFridgeObjects\annotations\96.xml, 129 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\97.xml
# Uploaded ./odFridgeObjects\annotations\97.xml, 130 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\98.xml
# Uploaded ./odFridgeObjects\annotations\98.xml, 131 files out of an estimated total of 260
# Uploading ./odFridgeObjects\annotations\99.xml
# Uploaded ./odFridgeObjects\annotations\99.xml, 132 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\1.jpg
# Uploaded ./odFridgeObjects\images\1.jpg, 133 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\10.jpg
# Uploaded ./odFridgeObjects\images\10.jpg, 134 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\100.jpg
# Uploaded ./odFridgeObjects\images\100.jpg, 135 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\101.jpg
# Uploaded ./odFridgeObjects\images\101.jpg, 136 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\102.jpg
# Uploaded ./odFridgeObjects\images\102.jpg, 137 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\103.jpg
# Uploaded ./odFridgeObjects\images\103.jpg, 138 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\104.jpg
# Uploaded ./odFridgeObjects\images\104.jpg, 139 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\105.jpg
# Uploaded ./odFridgeObjects\images\105.jpg, 140 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\106.jpg
# Uploaded ./odFridgeObjects\images\106.jpg, 141 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\107.jpg
# Uploaded ./odFridgeObjects\images\107.jpg, 142 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\108.jpg
# Uploaded ./odFridgeObjects\images\108.jpg, 143 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\109.jpg
# Uploaded ./odFridgeObjects\images\109.jpg, 144 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\11.jpg
# Uploaded ./odFridgeObjects\images\11.jpg, 145 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\110.jpg
# Uploaded ./odFridgeObjects\images\110.jpg, 146 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\111.jpg
# Uploaded ./odFridgeObjects\images\111.jpg, 147 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\112.jpg
# Uploaded ./odFridgeObjects\images\112.jpg, 148 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\113.jpg
# Uploaded ./odFridgeObjects\images\113.jpg, 149 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\114.jpg
# Uploaded ./odFridgeObjects\images\114.jpg, 150 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\115.jpg
# Uploaded ./odFridgeObjects\images\115.jpg, 151 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\116.jpg
# Uploaded ./odFridgeObjects\images\116.jpg, 152 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\117.jpg
# Uploaded ./odFridgeObjects\images\117.jpg, 153 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\118.jpg
# Uploaded ./odFridgeObjects\images\118.jpg, 154 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\119.jpg
# Uploaded ./odFridgeObjects\images\119.jpg, 155 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\12.jpg
# Uploaded ./odFridgeObjects\images\12.jpg, 156 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\120.jpg
# Uploaded ./odFridgeObjects\images\120.jpg, 157 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\121.jpg
# Uploaded ./odFridgeObjects\images\121.jpg, 158 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\122.jpg
# Uploaded ./odFridgeObjects\images\122.jpg, 159 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\123.jpg
# Uploaded ./odFridgeObjects\images\123.jpg, 160 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\124.jpg
# Uploaded ./odFridgeObjects\images\124.jpg, 161 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\125.jpg
# Uploaded ./odFridgeObjects\images\125.jpg, 162 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\126.jpg
# Uploaded ./odFridgeObjects\images\126.jpg, 163 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\127.jpg
# Uploaded ./odFridgeObjects\images\127.jpg, 164 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\128.jpg
# Uploaded ./odFridgeObjects\images\128.jpg, 165 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\13.jpg
# Uploaded ./odFridgeObjects\images\13.jpg, 166 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\14.jpg
# Uploaded ./odFridgeObjects\images\14.jpg, 167 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\15.jpg
# Uploaded ./odFridgeObjects\images\15.jpg, 168 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\16.jpg
# Uploaded ./odFridgeObjects\images\16.jpg, 169 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\17.jpg
# Uploaded ./odFridgeObjects\images\17.jpg, 170 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\18.jpg
# Uploaded ./odFridgeObjects\images\18.jpg, 171 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\19.jpg
# Uploaded ./odFridgeObjects\images\19.jpg, 172 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\2.jpg
# Uploaded ./odFridgeObjects\images\2.jpg, 173 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\20.jpg
# Uploaded ./odFridgeObjects\images\20.jpg, 174 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\21.jpg
# Uploaded ./odFridgeObjects\images\21.jpg, 175 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\22.jpg
# Uploaded ./odFridgeObjects\images\22.jpg, 176 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\23.jpg
# Uploaded ./odFridgeObjects\images\23.jpg, 177 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\24.jpg
# Uploaded ./odFridgeObjects\images\24.jpg, 178 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\25.jpg
# Uploaded ./odFridgeObjects\images\25.jpg, 179 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\26.jpg
# Uploaded ./odFridgeObjects\images\26.jpg, 180 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\27.jpg
# Uploaded ./odFridgeObjects\images\27.jpg, 181 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\28.jpg
# Uploaded ./odFridgeObjects\images\28.jpg, 182 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\29.jpg
# Uploaded ./odFridgeObjects\images\29.jpg, 183 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\3.jpg
# Uploaded ./odFridgeObjects\images\3.jpg, 184 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\30.jpg
# Uploaded ./odFridgeObjects\images\30.jpg, 185 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\31.jpg
# Uploaded ./odFridgeObjects\images\31.jpg, 186 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\32.jpg
# Uploaded ./odFridgeObjects\images\32.jpg, 187 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\33.jpg
# Uploaded ./odFridgeObjects\images\33.jpg, 188 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\34.jpg
# Uploaded ./odFridgeObjects\images\34.jpg, 189 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\35.jpg
# Uploaded ./odFridgeObjects\images\35.jpg, 190 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\36.jpg
# Uploaded ./odFridgeObjects\images\36.jpg, 191 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\37.jpg
# Uploaded ./odFridgeObjects\images\37.jpg, 192 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\38.jpg
# Uploaded ./odFridgeObjects\images\38.jpg, 193 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\39.jpg
# Uploaded ./odFridgeObjects\images\39.jpg, 194 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\4.jpg
# Uploaded ./odFridgeObjects\images\4.jpg, 195 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\40.jpg
# Uploaded ./odFridgeObjects\images\40.jpg, 196 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\41.jpg
# Uploaded ./odFridgeObjects\images\41.jpg, 197 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\42.jpg
# Uploaded ./odFridgeObjects\images\42.jpg, 198 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\43.jpg
# Uploaded ./odFridgeObjects\images\43.jpg, 199 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\44.jpg
# Uploaded ./odFridgeObjects\images\44.jpg, 200 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\45.jpg
# Uploaded ./odFridgeObjects\images\45.jpg, 201 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\46.jpg
# Uploaded ./odFridgeObjects\images\46.jpg, 202 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\47.jpg
# Uploaded ./odFridgeObjects\images\47.jpg, 203 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\48.jpg
# Uploaded ./odFridgeObjects\images\48.jpg, 204 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\49.jpg
# Uploaded ./odFridgeObjects\images\49.jpg, 205 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\5.jpg
# Uploaded ./odFridgeObjects\images\5.jpg, 206 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\50.jpg
# Uploaded ./odFridgeObjects\images\50.jpg, 207 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\51.jpg
# Uploaded ./odFridgeObjects\images\51.jpg, 208 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\52.jpg
# Uploaded ./odFridgeObjects\images\52.jpg, 209 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\53.jpg
# Uploaded ./odFridgeObjects\images\53.jpg, 210 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\54.jpg
# Uploaded ./odFridgeObjects\images\54.jpg, 211 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\55.jpg
# Uploaded ./odFridgeObjects\images\55.jpg, 212 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\56.jpg
# Uploaded ./odFridgeObjects\images\56.jpg, 213 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\57.jpg
# Uploaded ./odFridgeObjects\images\57.jpg, 214 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\58.jpg
# Uploaded ./odFridgeObjects\images\58.jpg, 215 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\59.jpg
# Uploaded ./odFridgeObjects\images\59.jpg, 216 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\6.jpg
# Uploaded ./odFridgeObjects\images\6.jpg, 217 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\60.jpg
# Uploaded ./odFridgeObjects\images\60.jpg, 218 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\61.jpg
# Uploaded ./odFridgeObjects\images\61.jpg, 219 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\62.jpg
# Uploaded ./odFridgeObjects\images\62.jpg, 220 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\63.jpg
# Uploaded ./odFridgeObjects\images\63.jpg, 221 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\64.jpg
# Uploaded ./odFridgeObjects\images\64.jpg, 222 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\65.jpg
# Uploaded ./odFridgeObjects\images\65.jpg, 223 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\66.jpg
# Uploaded ./odFridgeObjects\images\66.jpg, 224 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\67.jpg
# Uploaded ./odFridgeObjects\images\67.jpg, 225 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\68.jpg
# Uploaded ./odFridgeObjects\images\68.jpg, 226 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\69.jpg
# Uploaded ./odFridgeObjects\images\69.jpg, 227 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\7.jpg
# Uploaded ./odFridgeObjects\images\7.jpg, 228 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\70.jpg
# Uploaded ./odFridgeObjects\images\70.jpg, 229 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\71.jpg
# Uploaded ./odFridgeObjects\images\71.jpg, 230 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\72.jpg
# Uploaded ./odFridgeObjects\images\72.jpg, 231 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\73.jpg
# Uploaded ./odFridgeObjects\images\73.jpg, 232 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\74.jpg
# Uploaded ./odFridgeObjects\images\74.jpg, 233 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\75.jpg
# Uploaded ./odFridgeObjects\images\75.jpg, 234 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\76.jpg
# Uploaded ./odFridgeObjects\images\76.jpg, 235 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\77.jpg
# Uploaded ./odFridgeObjects\images\77.jpg, 236 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\78.jpg
# Uploaded ./odFridgeObjects\images\78.jpg, 237 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\79.jpg
# Uploaded ./odFridgeObjects\images\79.jpg, 238 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\8.jpg
# Uploaded ./odFridgeObjects\images\8.jpg, 239 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\80.jpg
# Uploaded ./odFridgeObjects\images\80.jpg, 240 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\81.jpg
# Uploaded ./odFridgeObjects\images\81.jpg, 241 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\82.jpg
# Uploaded ./odFridgeObjects\images\82.jpg, 242 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\83.jpg
# Uploaded ./odFridgeObjects\images\83.jpg, 243 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\85.jpg
# Uploaded ./odFridgeObjects\images\85.jpg, 244 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\86.jpg
# Uploaded ./odFridgeObjects\images\86.jpg, 245 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\87.jpg
# Uploaded ./odFridgeObjects\images\87.jpg, 246 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\88.jpg
# Uploaded ./odFridgeObjects\images\88.jpg, 247 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\89.jpg
# Uploaded ./odFridgeObjects\images\89.jpg, 248 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\91.jpg
# Uploaded ./odFridgeObjects\images\91.jpg, 249 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\84.jpg
# Uploaded ./odFridgeObjects\images\84.jpg, 250 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\90.jpg
# Uploaded ./odFridgeObjects\images\90.jpg, 251 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\94.jpg
# Uploaded ./odFridgeObjects\images\94.jpg, 252 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\9.jpg
# Uploaded ./odFridgeObjects\images\9.jpg, 253 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\92.jpg
# Uploaded ./odFridgeObjects\images\92.jpg, 254 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\93.jpg
# Uploaded ./odFridgeObjects\images\93.jpg, 255 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\95.jpg
# Uploaded ./odFridgeObjects\images\95.jpg, 256 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\97.jpg
# Uploaded ./odFridgeObjects\images\97.jpg, 257 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\98.jpg
# Uploaded ./odFridgeObjects\images\98.jpg, 258 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\99.jpg
# Uploaded ./odFridgeObjects\images\99.jpg, 259 files out of an estimated total of 260
# Uploading ./odFridgeObjects\images\96.jpg
# Uploaded ./odFridgeObjects\images\96.jpg, 260 files out of an estimated total of 260
# Uploaded 260 files
# $AZUREML_DATAREFERENCE_0487cc6f2d714f9d8c242908292d1ede

# %% [markdown]
# Finally, we need to create an [AzureML Tabular Dataset](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.data.tabulardataset) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.core import Dataset
from azureml.data import DataType

# get existing training dataset
training_dataset_name = "odFridgeObjectsTrainingDataset"
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print("Found the training dataset", training_dataset_name)
else:
    # create training dataset
    training_dataset = Dataset.Tabular.from_json_lines_files(
        path=ds.path("odFridgeObjects/train_annotations.jsonl"),
        set_column_types={"image_url": DataType.to_stream(ds.workspace)},
    )
    training_dataset = training_dataset.register(
        workspace=ws, name=training_dataset_name
    )
# get existing validation dataset
validation_dataset_name = "odFridgeObjectsValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print("Found the validation dataset", validation_dataset_name)
else:
    # create validation dataset
    validation_dataset = Dataset.Tabular.from_json_lines_files(
        path=ds.path("odFridgeObjects/validation_annotations.jsonl"),
        set_column_types={"image_url": DataType.to_stream(ds.workspace)},
    )
    validation_dataset = validation_dataset.register(
        workspace=ws, name=validation_dataset_name
    )
print("Training dataset name: " + training_dataset.name)
print("Validation dataset name: " + validation_dataset.name)
# Out:
# Training dataset name: odFridgeObjectsTrainingDataset
# Validation dataset name: odFridgeObjectsValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the [documentation](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#model-agnostic-hyperparameters) for more details.
#
# This is what the training dataset looks like:

# %%
training_dataset.to_pandas_dataframe()
# Out:
#                                              image_url  \
# 0     workspaceblobstore/odFridgeObjects/images/10.jpg
# 1    workspaceblobstore/odFridgeObjects/images/100.jpg
# 2    workspaceblobstore/odFridgeObjects/images/101.jpg
# 3    workspaceblobstore/odFridgeObjects/images/102.jpg
# 4    workspaceblobstore/odFridgeObjects/images/104.jpg
# ..                                                 ...
# 97    workspaceblobstore/odFridgeObjects/images/94.jpg
# 98    workspaceblobstore/odFridgeObjects/images/95.jpg
# 99    workspaceblobstore/odFridgeObjects/images/96.jpg
# 100   workspaceblobstore/odFridgeObjects/images/98.jpg
# 101   workspaceblobstore/odFridgeObjects/images/99.jpg
#
#                                       image_details  \
# 0    {'format': 'jpg', 'width': 499, 'height': 666}
# 1    {'format': 'jpg', 'width': 499, 'height': 666}
# 2    {'format': 'jpg', 'width': 499, 'height': 666}
# 3    {'format': 'jpg', 'width': 499, 'height': 666}
# 4    {'format': 'jpg', 'width': 499, 'height': 666}
# ..                                              ...
# 97   {'format': 'jpg', 'width': 499, 'height': 666}
# 98   {'format': 'jpg', 'width': 499, 'height': 666}
# 99   {'format': 'jpg', 'width': 499, 'height': 666}
# 100  {'format': 'jpg', 'width': 499, 'height': 666}
# 101  {'format': 'jpg', 'width': 499, 'height': 666}
#
#                                                  label
# 0    [{'label': 'carton', 'topX': 0.172344689378757...
# 1    [{'label': 'can', 'topX': 0.2605210420841683, ...
# 2    [{'label': 'water_bottle', 'topX': 0.130260521...
# 3    [{'label': 'water_bottle', 'topX': 0.278557114...
# 4    [{'label': 'can', 'topX': 0.35070140280561124,...
# ..                                                 ...
# 97   [{'label': 'carton', 'topX': 0.036072144288577...
# 98   [{'label': 'carton', 'topX': 0.208416833667334...
# 99   [{'label': 'carton', 'topX': 0.172344689378757...
# 100  [{'label': 'carton', 'topX': 0.090180360721442...
# 101  [{'label': 'can', 'topX': 0.3046092184368738, ...
#
# [102 rows x 3 columns]

# %% [markdown]
# ## Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML Image run are specified using the `AutoMLImageConfig` - please refer to the [documentation](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#configure-your-experiment-settings) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple models. Please refer to the [documentation](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#configure-model-algorithms-and-hyperparameters) for the list of supported model algorithms.

# %% [markdown]
# ### Using default hyperparameter values for the specified algorithm
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values for a given model to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This allows an iterative approach, as with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially, and  you need more iterations to find optimal configurations.
#
# If you wish to use the default hyperparameter values for a given algorithm (say `yolov5`), you can specify the config for your AutoML Image runs as follows:

# %%
from azureml.automl.core.shared.constants import ImageTask
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import GridParameterSampling, choice

image_config_yolov5 = AutoMLImageConfig(
    task=ImageTask.IMAGE_OBJECT_DETECTION,
    compute_target=compute_target,
    training_data=training_dataset,
    validation_data=validation_dataset,
    hyperparameter_sampling=GridParameterSampling({"model_name": choice("yolov5")}),
    iterations=1,
)

# %% [markdown]
# ## Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, you can submit an AutoML run using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config_yolov5)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>automl-image-object-detection</td><td>AutoML_c85c842b-0f76-49d5-9d0b-4c7d1418bb54</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_c85c842b-0f76-49d5-9d0b-4c7d1418bb54?wsid=/subscriptions/3191ba83-be2b-4b29-8409-f06e2fbb65bd/resourcegroups/DAWECoPConference/workspaces/DAWECoPConference&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_c85c842b-0f76-49d5-9d0b-4c7d1418bb54',
#  'target': 'gpu-cluster-nc6',
#  'status': 'Completed',
#  'startTimeUtc': '2022-06-05T22:24:41.920705Z',
#  'endTimeUtc': '2022-06-05T22:41:27.820397Z',
#  'services': {},
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'mean_average_precision',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-cluster-nc6',
#   'AMLSettingsJsonString': '{"path":null,"name":"automl-image-object-detection","subscription_id":"3191ba83-be2b-4b29-8409-f06e2fbb65bd","resource_group":"DAWECoPConference","workspace_name":"DAWECoPConference","region":"australiaeast","compute_target":"gpu-cluster-nc6","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"mean_average_precision","task_type":"image-object-detection","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":true,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"partition_column_names":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"090c9fba-f1f9-4abe-b4b1-55db00228fe7","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"yolov5\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"cb62ad6d-7aff-4cdb-be47-d1ee9f45c5a3","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"090c9fba-f1f9-4abe-b4b1-55db00228fe7\\"}, \\"validation_data\\": {\\"datasetId\\": \\"cb62ad6d-7aff-4cdb-be47-d1ee9f45c5a3\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'AutoMLImageSDK',
#   'display_task_type': 'image-object-detection',
#   'dependencies_versions': '{"azureml-training-tabular": "1.41.1", "azureml-train-restclients-hyperdrive": "1.41.0", "azureml-train-core": "1.41.0", "azureml-train-automl": "1.41.0", "azureml-train-automl-runtime": "1.41.1", "azureml-train-automl-client": "1.41.0", "azureml-telemetry": "1.41.0", "azureml-mlflow": "1.41.0.post1", "azureml-interpret": "1.41.0", "azureml-inference-server-http": "0.4.11", "azureml-defaults": "1.41.0", "azureml-dataset-runtime": "1.41.0", "azureml-dataprep": "3.1.3", "azureml-dataprep-rslex": "2.5.4", "azureml-dataprep-native": "38.0.0", "azureml-core": "1.41.0.post1", "azureml-automl-runtime": "1.41.1", "azureml-automl-core": "1.41.1.post1"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'AutoMLImageSDK',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://australiaeast.api.azureml.ms/jasmine/v1.0/subscriptions/3191ba83-be2b-4b29-8409-f06e2fbb65bd/resourceGroups/DAWECoPConference/providers/Microsoft.MachineLearningServices/workspaces/DAWECoPConference/experimentids/cb0b8a61-1ffa-46c3-a5a6-a4518503bdc4/cancel/AutoML_c85c842b-0f76-49d5-9d0b-4c7d1418bb54',
#   'azureml.git.repository_uri': 'https://github.com/Azure/azureml-examples',
#   'mlflow.source.git.repoURL': 'https://github.com/Azure/azureml-examples',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '691549fbfb389d0bdd2ee853584b779d902d860d',
#   'mlflow.source.git.commit': '691549fbfb389d0bdd2ee853584b779d902d860d',
#   'azureml.git.dirty': 'True',
#   'ClientSdkVersion': '1.42.0.post1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '090c9fba-f1f9-4abe-b4b1-55db00228fe7'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': 'cb62ad6d-7aff-4cdb-be47-d1ee9f45c5a3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Steve Van Bodegraven'}

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# In this example, we use the AutoMLImageConfig to train an Object Detection model using `yolov5` and `fasterrcnn_resnet50_fpn`, both of which are pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label categories.
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, choosing from a range of values for `learning_rate`, `optimizer`, `lr_scheduler`, etc., to generate a model with the optimal primary metric. If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use Random Sampling to pick samples from this parameter space and try a total of 10 iterations with these different samples, running 2 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We leverage the Bandit early termination policy which will terminate poor performing configs (those that are not within 20% slack of the best performing config), thus significantly saving compute resources.
#
# For more details on model and hyperparameter sweeping, please refer to the [documentation](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-tune-hyperparameters).

# %%
from azureml.automl.core.shared.constants import ImageTask
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import BanditPolicy, RandomParameterSampling
from azureml.train.hyperdrive import choice, uniform

parameter_space = {
    "model": choice(
        {
            "model_name": choice("yolov5"),
            "learning_rate": uniform(0.0001, 0.01),
            "model_size": choice("small", "medium"),  # model-specific
            #'img_size': choice(640, 704, 768), # model-specific; might need GPU with large memory
        },
        {
            "model_name": choice("fasterrcnn_resnet50_fpn"),
            "learning_rate": uniform(0.0001, 0.001),
            "optimizer": choice("sgd", "adam", "adamw"),
            "min_size": choice(600, 800),  # model-specific
            #'warmup_cosine_lr_warmup_epochs': choice(0, 3),
        },
    ),
}

tuning_settings = {
    "iterations": 10,
    "max_concurrent_iterations": 2,
    "hyperparameter_sampling": RandomParameterSampling(parameter_space),
    "early_termination_policy": BanditPolicy(
        evaluation_interval=2, slack_factor=0.2, delay_evaluation=6
    ),
}

automl_image_config = AutoMLImageConfig(
    task=ImageTask.IMAGE_OBJECT_DETECTION,
    compute_target=compute_target,
    training_data=training_dataset,
    validation_data=validation_dataset,
    **tuning_settings,
)

# %%
automl_image_run = experiment.submit(automl_image_config)

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)

# %% [markdown]
# When doing a hyperparameter sweep, it can be useful to visualize the different configurations that were tried using the HyperDrive UI. You can navigate to this UI by going to the 'Child runs' tab in the UI of the main `automl_image_run` from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this HyperDrive parent run. Alternatively, here below you can see directly the HyperDrive parent run and navigate to its 'Child runs' tab:

# %%
from azureml.core import Run

hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + "_HD")
hyperdrive_run

# %% [markdown]
# ## Register the optimal vision model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
# Register the model from the best run

best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties["model_name"]
model = best_child_run.register_model(
    model_name=model_name, model_path="outputs/model.pt"
)

# %% [markdown]
# ## Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)). Please note that ACI only supports small models under 1 GB in size. For testing larger models or for the high-scale production stage, we recommend using AKS.
# In this tutorial, we will deploy the model as a web service in AKS.

# %% [markdown]
# You will need to first create an AKS compute cluster or use an existing AKS cluster. You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "aks-cpu-od"
# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print("Found existing compute target")
except ComputeTargetException:
    print("Creating a new compute target...")
    # Provision AKS cluster with a CPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_D3_V2")
    # Create the cluster
    aks_target = ComputeTarget.create(
        workspace=ws, name=aks_name, provisioning_configuration=prov_config
    )
    aks_target.wait_for_completion(show_output=True)
# Out:
# Creating a new compute target...
# InProgress........................................................................................
# SucceededProvisioning operation finished, operation "Succeeded"

# %% [markdown]
# Next, you will need to define the [inference configuration](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-auto-train-image-models#update-inference-configuration), that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
#
# <b>Note:</b> To change the model's settings, open the downloaded scoring script and modify the model_settings variable <i>before</i> deploying the model.

# %%
from azureml.core.model import InferenceConfig

best_child_run.download_file(
    "outputs/scoring_file_v_1_0_0.py", output_file_path="score.py"
)
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script="score.py", environment=environment)

# %% [markdown]
# You can then deploy the model as an AKS web service.

# %%
# Deploy the model from the best run as an AKS web service
from azureml.core.webservice import AksWebservice
from azureml.core.model import Model

aks_config = AksWebservice.deploy_configuration(
    autoscale_enabled=True, cpu_cores=1, memory_gb=5, enable_app_insights=True
)

aks_service = Model.deploy(
    ws,
    models=[model],
    inference_config=inference_config,
    deployment_config=aks_config,
    deployment_target=aks_target,
    name="automl-image-test-cpu-od",
    overwrite=True,
)
aks_service.wait_for_deployment(show_output=True)
print(aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2022-06-06 08:30:10+09:30 Creating Container Registry if not exists..
# 2022-06-06 08:40:10+09:30 Registering the environment.
# 2022-06-06 08:40:11+09:30 Use the existing image.
# 2022-06-06 08:40:12+09:30 Creating resources in AKS.
# 2022-06-06 08:40:13+09:30 Submitting deployment to compute.
# 2022-06-06 08:40:13+09:30 Checking the status of deployment automl-image-test-cpu-od..
# 2022-06-06 08:45:53+09:30 Checking the status of inference endpoint automl-image-test-cpu-od.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ## Test the web service
# Finally, let's test our deployed web service to predict new images. You can pass in any image. In this case, we'll use a random image from the dataset and pass it to the scoring URI.

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

sample_image = "./test_image.jpg"

# Load image data
data = open(sample_image, "rb").read()

# Set the content type
headers = {"Content-Type": "application/octet-stream"}

# If authentication is enabled, set the authorization header
headers["Authorization"] = f"Bearer {key}"

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print(resp.text)
# Out:
# {"filename": "/tmp/tmpq_835i3c/tmpjbfx4bfk", "boxes": [{"box": {"topX": 0.21833995588139352, "topY": 0.2827195644378662, "bottomX": 0.40959922456044495, "bottomY": 0.6184663295745849}, "label": "milk_bottle", "score": 0.9132057428359985}, {"box": {"topX": 0.6929107220038492, "topY": 0.48620100021362306, "bottomX": 0.935708446144311, "bottomY": 0.8133646965026855}, "label": "can", "score": 0.902458131313324}, {"box": {"topX": 0.42592663854547236, "topY": 0.2717799186706543, "bottomX": 0.6243817482711378, "bottomY": 0.7014404296875}, "label": "water_bottle", "score": 0.8939341306686401}]}

# %% [markdown]
# ## Visualize detections
# Now that we have scored a test image, we can visualize the bounding boxes for this image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18, 12)
plt.figure(figsize=IMAGE_SIZE)
img_np = mpimg.imread(sample_image)
img = Image.fromarray(img_np.astype("uint8"), "RGB")
x, y = img.size

fig, ax = plt.subplots(1, figsize=(15, 15))
# Display the image
ax.imshow(img_np)

# draw box and label for each detection
detections = json.loads(resp.text)
for detect in detections["boxes"]:
    label = detect["label"]
    box = detect["box"]
    conf_score = detect["score"]
    if conf_score > 0.6:
        ymin, xmin, ymax, xmax = (
            box["topY"],
            box["topX"],
            box["bottomY"],
            box["bottomX"],
        )
        topleft_x, topleft_y = x * xmin, y * ymin
        width, height = x * (xmax - xmin), y * (ymax - ymin)
        print(
            "{}: [{}, {}, {}, {}], {}".format(
                detect["label"],
                round(topleft_x, 3),
                round(topleft_y, 3),
                round(width, 3),
                round(height, 3),
                round(conf_score, 3),
            )
        )

        color = np.random.rand(3)  #'red'
        rect = patches.Rectangle(
            (topleft_x, topleft_y),
            width,
            height,
            linewidth=3,
            edgecolor=color,
            facecolor="none",
        )

        ax.add_patch(rect)
        plt.text(topleft_x, topleft_y - 10, label, color=color, fontsize=20)
plt.show()
# Out:
# milk_bottle: [108.952, 188.291, 95.438, 223.607], 0.913
# can: [345.762, 323.81, 121.156, 217.891], 0.902
# water_bottle: [212.537, 181.005, 99.029, 286.154], 0.894
